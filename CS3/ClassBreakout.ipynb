# %%
import os
import email

os.listdir(".")
# X = os.listdir(".\\easy_ham")
# with open(os.path.join(".\\easy_ham",X[0], "r")) as file_handler:
#     msg = file_handler.read()
# last one isn't working for me yet
# Out:
# ['.ipynb_checkpoints',
#  'ClassBreakout.ipynb',
#  'easy_ham',
#  'easy_ham_2',
#  'hard_ham',
#  'spam',
#  'SpamAssassinMessages.zip',
#  'spam_2']

# %%
# open a file
X = os.listdir(".\\easy_ham")
with open(os.path.join(".\\easy_ham",X[0]), "r") as file_handler:
    msg = file_handler.read()

# %%
X[0]
# Out:
# '00001.7c53336b37003a9286aba55d2945844c'

# %%
# "r" = read, "w" = read/write
count = 0
for msg in X:
    path_ = os.path.join(".\\easy_ham",msg) 
    with open(path_, "r") as file_handler:
        msg = file_handler.read()
        if count % 20 == 0:
            print(count)
        count+=1
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100
# 1120
# 1140
# 1160
# 1180
# 1200
# 1220
# 1240
# 1260
# 1280
# 1300
# 1320
# 1340
# 1360
# 1380
# 1400
# 1420
# 1440
# 1460
# 1480
# 1500
# 1520
# 1540
# 1560
# 1580
# 1600
# 1620
# 1640
# 1660
# 1680
# 1700
# 1720
# 1740
# 1760
# 1780
# 1800
# 1820
# 1840
# 1860
# 1880
# 1900
# 1920
# 1940
# 1960
# 1980
# 2000
# 2020
# 2040
# 2060
# 2080
# 2100
# 2120
# 2140
# 2160
# 2180
# 2200
# 2220
# 2240
# 2260
# 2280
# 2300
# 2320
# 2340
# 2360
# 2380
# 2400
# 2420
# 2440
# 2460
# 2480
# 2500
# 2520
# 2540
# 2560
# 2580
# 2600
# 2620
# 2640
# 2660
# 2680
# 2700
# 2720
# 2740
# 2760
# 2780
# 2800
# 2820
# 2840
# 2860
# 2880
# 2900
# 2920
# 2940
# 2960
# 2980
# ...

# %%
# for every directory found print it out
for root, dirs, files in os.walk("."):
    for d in dirs:
        print(d)
# Out:
# .ipynb_checkpoints
# easy_ham
# easy_ham_2
# hard_ham
# spam
# spam_2

# %%
# folder it is in, along with the message
for root, dirs, files in os.walk("."):
    for f in files:
        print(os.path.join(root, f))
# Out:
# .\ClassBreakout.ipynb
# .\SpamAssassinMessages.zip
# .\.ipynb_checkpoints\ClassBreakout-checkpoint.ipynb
# .\.ipynb_checkpoints\Untitled-checkpoint.ipynb
# .\easy_ham\00001.7c53336b37003a9286aba55d2945844c
# .\easy_ham\00002.9c4069e25e1ef370c078db7ee85ff9ac
# .\easy_ham\00003.860e3c3cee1b42ead714c5c874fe25f7
# .\easy_ham\00004.864220c5b6930b209cc287c361c99af1
# .\easy_ham\00005.bf27cdeaf0b8c4647ecd61b1d09da613
# .\easy_ham\00006.253ea2f9a9cc36fa0b1129b04b806608
# .\easy_ham\00007.37a8af848caae585af4fe35779656d55
# .\easy_ham\00008.5891548d921601906337dcf1ed8543cb
# .\easy_ham\00009.371eca25b0169ce5cb4f71d3e07b9e2d
# .\easy_ham\0001.ea7e79d3153e7469e7a9c3e0af6a357e
# .\easy_ham\00010.145d22c053c1a0c410242e46c01635b3
# .\easy_ham\00011.fbcde1b4833bdbaaf0ced723edd6e355
# .\easy_ham\00012.48a387bc38d1316a6f6b49e8c2e43a03
# .\easy_ham\00013.81c34741dbed59c6dde50777e27e7ea3
# .\easy_ham\00014.cb20e10b2bfcb8210a1c310798532a57
# .\easy_ham\00015.4d7026347ba7478c9db04c70913e68fd
# ...

# %%
file_name = []
label = []
for root, dirs, files in os.walk("."):
    for f in files:
        if "spam" in root:
            label.append("spam")
        else:
            label.append("not_spam")
        file_name.append(os.path.join(root,f))

# %%
import pandas as pd
data = pd.DataFrame({"Message":file_name,"Target":label})

# %%
#need to eliminate ipynb and zip files
data
# Out:
#                                                 Message    Target
# 0                                 .\ClassBreakout.ipynb  not_spam
# 1                            .\SpamAssassinMessages.zip  not_spam
# 2     .\.ipynb_checkpoints\ClassBreakout-checkpoint....  not_spam
# 3        .\.ipynb_checkpoints\Untitled-checkpoint.ipynb  not_spam
# 4     .\easy_ham\00001.7c53336b37003a9286aba55d2945844c  not_spam
# ...                                                 ...       ...
# 9352    .\spam_2\01397.f75f0dd0dd923faefa3e9cc5ecb8c906      spam
# 9353    .\spam_2\01398.8ca7045aae4184d56e8509dc5ad6d979      spam
# 9354    .\spam_2\01399.2319643317e2c5193d574e40a71809c2      spam
# 9355    .\spam_2\01400.b444b69845db2fa0a4693ca04e6ac5c5      spam
# 9356                                      .\spam_2\cmds      spam
#
# [9357 rows x 2 columns]

# %%
# file_name = "D:\\SMUMSDS\\QuantWorld\\CS3\\Spam"

# %%
# with open(os.path.join("D:\\SMUMSDS\\QuantWorld\\CS3\\spam\\00001.7848dde101aa985090474a91ec93fcf0"), 'r') as file_handler:
#   msg = file_handler.read()

# %%
print(msg)
# Out:
# mv 00001.7c53336b37003a9286aba55d2945844c 00001.7c53336b37003a9286aba55d2945844c
# mv 00002.9c4069e25e1ef370c078db7ee85ff9ac 00002.9c4069e25e1ef370c078db7ee85ff9ac
# mv 00003.860e3c3cee1b42ead714c5c874fe25f7 00003.860e3c3cee1b42ead714c5c874fe25f7
# mv 00004.864220c5b6930b209cc287c361c99af1 00004.864220c5b6930b209cc287c361c99af1
# mv 00005.bf27cdeaf0b8c4647ecd61b1d09da613 00005.bf27cdeaf0b8c4647ecd61b1d09da613
# mv 00006.253ea2f9a9cc36fa0b1129b04b806608 00006.253ea2f9a9cc36fa0b1129b04b806608
# mv 00007.37a8af848caae585af4fe35779656d55 00007.37a8af848caae585af4fe35779656d55
# mv 00008.5891548d921601906337dcf1ed8543cb 00008.5891548d921601906337dcf1ed8543cb
# mv 00009.371eca25b0169ce5cb4f71d3e07b9e2d 00009.371eca25b0169ce5cb4f71d3e07b9e2d
# mv 00010.145d22c053c1a0c410242e46c01635b3 00010.145d22c053c1a0c410242e46c01635b3
# mv 00011.fbcde1b4833bdbaaf0ced723edd6e355 00011.fbcde1b4833bdbaaf0ced723edd6e355
# mv 00012.48a387bc38d1316a6f6b49e8c2e43a03 00012.48a387bc38d1316a6f6b49e8c2e43a03
# ...

# %%
from email import message_from_bytes

# Assuming `email_data` is a byte string containing the raw data of the email
# email_message = message_from_bytes(msg)
email_message = message_from_bytes(msg.encode("utf-8"))

# Loop through all parts of the email
for part in email_message.walk():
    if part.get_content_type() == "text/plain":
        # Get the text of the body of the email
        body = part.get_payload(decode=True)
        print(body.decode())
# Out:
# mv 00001.7c53336b37003a9286aba55d2945844c 00001.7c53336b37003a9286aba55d2945844c
# mv 00002.9c4069e25e1ef370c078db7ee85ff9ac 00002.9c4069e25e1ef370c078db7ee85ff9ac
# mv 00003.860e3c3cee1b42ead714c5c874fe25f7 00003.860e3c3cee1b42ead714c5c874fe25f7
# mv 00004.864220c5b6930b209cc287c361c99af1 00004.864220c5b6930b209cc287c361c99af1
# mv 00005.bf27cdeaf0b8c4647ecd61b1d09da613 00005.bf27cdeaf0b8c4647ecd61b1d09da613
# mv 00006.253ea2f9a9cc36fa0b1129b04b806608 00006.253ea2f9a9cc36fa0b1129b04b806608
# mv 00007.37a8af848caae585af4fe35779656d55 00007.37a8af848caae585af4fe35779656d55
# mv 00008.5891548d921601906337dcf1ed8543cb 00008.5891548d921601906337dcf1ed8543cb
# mv 00009.371eca25b0169ce5cb4f71d3e07b9e2d 00009.371eca25b0169ce5cb4f71d3e07b9e2d
# mv 00010.145d22c053c1a0c410242e46c01635b3 00010.145d22c053c1a0c410242e46c01635b3
# mv 00011.fbcde1b4833bdbaaf0ced723edd6e355 00011.fbcde1b4833bdbaaf0ced723edd6e355
# mv 00012.48a387bc38d1316a6f6b49e8c2e43a03 00012.48a387bc38d1316a6f6b49e8c2e43a03
# ...

# %%
# no errors occured
from collections import Counter
types = Counter()
for root,dirs,files in os.walk("."):
    for f in files:
        with open(os.path.join(root,f),'r',encoding='latin-1') as file_point:
#              try:   
                msg = email.message_from_file(file_point, )
                body = msg.get_payload()
                t = msg.get_content_type()
                types[t]+=1
                break
#              except:            
#                 print(f"an error occured on {os.path.join(root,f)}")

# %%
# replace the "n"'s
from sklearn.feature_extraction.text import CountVectorizer
counts = CountVectorizer(input=body.replace("\n", " "))
# counts.fit(,encoding='latin-1')
# body.replace("\n", " ").split(" ")

# %%
body.replace("\n", " ")
# Out:
# 'Greetings!  You are receiving this letter because you have expressed an interest in  receiving information about online business opportunities. If this is  erroneous then please accept my most sincere apology. This is a one-time  mailing, so no removal is necessary.  If you\'ve been burned, betrayed, and back-stabbed by multi-level marketing,  MLM, then please read this letter. It could be the most important one that  has ever landed in your Inbox.  MULTI-LEVEL MARKETING IS A HUGE MISTAKE FOR MOST PEOPLE  MLM has failed to deliver on its promises for the past 50 years. The pursuit  of the "MLM Dream" has cost hundreds of thousands of people their friends,  their fortunes and their sacred honor. The fact is that MLM is fatally  flawed, meaning that it CANNOT work for most people.  The companies and the few who earn the big money in MLM are NOT going to  tell you the real story. FINALLY, there is someone who has the courage to  cut through the hype and lies and tell the TRUTH about ML
# ...

# %%
types
# Out:
# Counter({'text/plain': 7417,
#          'multipart/signed': 180,
#          'multipart/alternative': 326,
#          'multipart/mixed': 179,
#          'multipart/related': 56,
#          'multipart/report': 5,
#          'text/html': 1193,
#          'text/plain charset=us-ascii': 1})

# %%
# create count vectorizer mainly 1 and 0's
