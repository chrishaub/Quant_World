# %%
loc = '/Users/alonsosalcido/Desktop/Quantifying the World/Case 3/SpamAssassinMessages'

# %%
import numpy as np
import os
os.listdir(loc)
# Out:
# ['spam',
#  'hard_ham',
#  'Untitled1.ipynb',
#  'spam_2',
#  '.DS_Store',
#  'Untitled.ipynb',
#  'easy_ham',
#  'Case 3.ipynb',
#  '.ipynb_checkpoints',
#  'easy_ham_2']

# %% [markdown]
# ## Count Files

# %%
spam = os.listdir(os.path.join(loc, 'spam'))
spam_2 = os.listdir(os.path.join(loc, 'spam_2'))

print("spam =",len(spam))
print("spam_2 =",len(spam_2))
# Out:
# spam = 1001
# spam_2 = 1398

# %%
hard_ham = os.listdir(os.path.join(loc,"./hard_ham"))
easy_ham = os.listdir(os.path.join(loc,"./easy_ham"))
easy_ham_2 = os.listdir(os.path.join(loc,"./easy_ham_2"))

print("hard_ham =", len(hard_ham))
print("easy_ham =",len(easy_ham))
print("easy_ham_2 =",len(easy_ham_2))
# Out:
# hard_ham = 501
# easy_ham = 5052
# easy_ham_2 = 1401

# %% [markdown]
# ### Count the number of files using specific decoder

# %%
x = os.listdir(os.path.join(loc,"./easy_ham"))

# %%
count = 0
for msg in x:
    path_ = os.path.join(os.path.join(loc,"./easy_ham",msg))
    with open(path_,"r", encoding="latin-1") as file_handler:
        msg = file_handler.read()
        if count % 20 == 0:
            print(count)
        count+=1
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100
# 1120
# 1140
# 1160
# 1180
# 1200
# 1220
# 1240
# 1260
# 1280
# 1300
# 1320
# 1340
# 1360
# 1380
# 1400
# 1420
# 1440
# 1460
# 1480
# 1500
# 1520
# 1540
# 1560
# 1580
# 1600
# 1620
# 1640
# 1660
# 1680
# 1700
# 1720
# 1740
# 1760
# 1780
# 1800
# 1820
# 1840
# 1860
# 1880
# 1900
# 1920
# 1940
# 1960
# 1980
# 2000
# 2020
# 2040
# 2060
# 2080
# 2100
# 2120
# 2140
# 2160
# 2180
# 2200
# 2220
# 2240
# 2260
# 2280
# 2300
# 2320
# 2340
# 2360
# 2380
# 2400
# 2420
# 2440
# 2460
# 2480
# 2500
# 2520
# 2540
# 2560
# 2580
# 2600
# 2620
# 2640
# 2660
# 2680
# 2700
# 2720
# 2740
# 2760
# 2780
# 2800
# 2820
# 2840
# 2860
# 2880
# 2900
# 2920
# 2940
# 2960
# 2980
# 3000
# 3020
# 3040
# 3060
# 3080
# 3100
# 3120
# 3140
# 3160
# 3180
# 3200
# 3220
# 3240
# 3260
# 3280
# 3300
# 3320
# 3340
# 3360
# 3380
# 3400
# 3420
# 3440
# 3460
# 3480
# 3500
# 3520
# 3540
# 3560
# 3580
# 3600
# 3620
# 3640
# 3660
# 3680
# 3700
# 3720
# 3740
# 3760
# 3780
# 3800
# 3820
# 3840
# 3860
# 3880
# 3900
# 3920
# 3940
# 3960
# 3980
# 4000
# 4020
# 4040
# 4060
# 4080
# 4100
# 4120
# 4140
# 4160
# 4180
# 4200
# 4220
# 4240
# 4260
# 4280
# 4300
# 4320
# 4340
# 4360
# 4380
# 4400
# 4420
# 4440
# 4460
# 4480
# 4500
# 4520
# 4540
# 4560
# 4580
# 4600
# 4620
# 4640
# 4660
# 4680
# 4700
# 4720
# 4740
# 4760
# 4780
# 4800
# 4820
# 4840
# 4860
# 4880
# 4900
# 4920
# 4940
# 4960
# 4980
# 5000
# 5020
# 5040

# %%
y = os.listdir(os.path.join(loc,"./hard_ham"))

# %%
count = 0
for msg in y:
    path_ = os.path.join(os.path.join(loc,"./hard_ham",msg))
    with open(path_,"r", encoding="latin-1") as file_handler:
        msg = file_handler.read()
        if count % 20 == 0:
            print(count)
        count+=1
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500

# %% [markdown]
# ### Get the labels for all our emails

# %%
"""
Exclude Extensions that are not relevant
"""
file_name = []
label = []
extensions_to_exclude = ['.ipynb', '.DS_Store', 'cmds']

for root,dirs,files in os.walk(os.path.join(loc,".")):
    for f in files:
        if any(f.endswith(ext) for ext in extensions_to_exclude):
            continue
        if "spam" in root:
            label.append(1)
        else:
            label.append(0)
        file_name.append(os.path.join(root,f))

# %% [markdown]
# ### Create a data frame

# %%
import pandas as pd
data = pd.DataFrame({"Message":file_name,"Target":label})

# %%
print(data['Message'])
# Out:
# 0       /Users/alonsosalcido/Desktop/Quantifying the W...
# 1       /Users/alonsosalcido/Desktop/Quantifying the W...
# 2       /Users/alonsosalcido/Desktop/Quantifying the W...
# 3       /Users/alonsosalcido/Desktop/Quantifying the W...
# 4       /Users/alonsosalcido/Desktop/Quantifying the W...
#                               ...
# 9343    /Users/alonsosalcido/Desktop/Quantifying the W...
# 9344    /Users/alonsosalcido/Desktop/Quantifying the W...
# 9345    /Users/alonsosalcido/Desktop/Quantifying the W...
# 9346    /Users/alonsosalcido/Desktop/Quantifying the W...
# 9347    /Users/alonsosalcido/Desktop/Quantifying the W...
# Name: Message, Length: 9348, dtype: object

# %% [markdown]
# ### Read in text messages

# %%
import email

"""
Lets count the types of messages we have first
"""
from collections import Counter
types = Counter()
msgs = []
trigger = True
for root,dirs,files in os.walk(os.path.join(loc,"./")):
    for f in files:
        with open(os.path.join(root,f),'r',encoding='latin-1') as file_point:
            msg = email.message_from_file(file_point, )
            type_ = msg.get_content_type()
            types[type_]+=1
            if type_ == 'multipart/mixed' and trigger:
                print(msg.get_payload())
                print("________")
                trigger = False

print(types)
# Out:
# [<email.message.Message object at 0x7fa7d4962400>]
# ________
# Counter({'text/plain': 7420, 'text/html': 1193, 'multipart/alternative': 326, 'multipart/signed': 180, 'multipart/mixed': 179, 'multipart/related': 56, 'multipart/report': 5, 'text/plain charset=us-ascii': 1})

# %%
import os
import email
from bs4 import BeautifulSoup

extensions_to_exclude = ['.ipynb', '.DS_Store', 'cmds']
msgs = []
for root,dirs,files in os.walk(os.path.join(loc,"./")):
    for f in files:
        if any(f.endswith(ext) for ext in extensions_to_exclude):
            continue
        file_path = os.path.join(root,f)
        
        with open(file_path, "r",encoding='latin-1') as file:
            message = email.message_from_file(file)
        for part in message.walk():
            if part.get_content_type() in ["text/plain", "text/html"]:
                if part.get_content_type() == "text/html":
                    soup = BeautifulSoup(part.get_payload(decode=True).decode("latin-1"), "html.parser")
                    body = soup.get_text()
                else:
                    body = part.get_payload(decode=True).decode("latin-1")
        msgs.append(body)

# %%
print(len(msgs))
# Out:
# 9348

# %%
data['messages'] = msgs

# %% [markdown]
# ### Clean Text

# %%
##sart by removing \n
data['messages'] = data['messages'].str.replace("\n", " ")

# %%
data
# Out:
#                                                 Message  Target  \
# 0     /Users/alonsosalcido/Desktop/Quantifying the W...       1
# 1     /Users/alonsosalcido/Desktop/Quantifying the W...       1
# 2     /Users/alonsosalcido/Desktop/Quantifying the W...       1
# 3     /Users/alonsosalcido/Desktop/Quantifying the W...       1
# 4     /Users/alonsosalcido/Desktop/Quantifying the W...       1
# ...                                                 ...     ...
# 9343  /Users/alonsosalcido/Desktop/Quantifying the W...       0
# 9344  /Users/alonsosalcido/Desktop/Quantifying the W...       0
# 9345  /Users/alonsosalcido/Desktop/Quantifying the W...       0
# 9346  /Users/alonsosalcido/Desktop/Quantifying the W...       0
# 9347  /Users/alonsosalcido/Desktop/Quantifying the W...       0
#
#                                                messages
# 0     Dear Homeowner,   Interest Rates are at their ...
# 1     Backup your DVD's                     With DVD...
# 2       5% Guaranteed for Eight Years               ...
# 3      Congratulations! You Get a Free Handheld Orga...
# 4     ATTENTION: This is a MUST for ALL Computer Use...
# ...                                                 ...
# 9343  I'm one of the 30,000 but it's not working ver...
# 9344  Damien Morton quoted: >W3C approves HTML 4 'em...
# 9345  On Mon, 2002-07-22 at 06:50, che wrote:  > tha...
# 9346  Once upon a time, Manfred wrote :  > I would l...
# 9347  If you run Pick, and then use the "New FTOC" b...
#
# [9348 rows x 3 columns]

# %%
data['messages'][9345]
# Out:
# 'On Mon, 2002-07-22 at 06:50, che wrote:  > thats the correct lines to be added to sources.list for the repository > i just did a apt-get install gnome-session its still progressing :)  Excellent - might give it a bash tonight :)   _______________________________________________ RPM-List mailing list <RPM-List@freshrpms.net> http://lists.freshrpms.net/mailman/listinfo/rpm-list   '

# %%
import re

def replace_urls(text):
    # Regular expression pattern to match URLs
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    return re.sub(url_pattern, "URL", text)

data['messages'] = data['messages'].apply(replace_urls)

# %%
data['messages'][9345]
# Out:
# 'On Mon, 2002-07-22 at 06:50, che wrote:  > thats the correct lines to be added to sources.list for the repository > i just did a apt-get install gnome-session its still progressing :)  Excellent - might give it a bash tonight :)   _______________________________________________ RPM-List mailing list <RPM-List@freshrpms.net> URL   '

# %%
# Remove unwanted characters using regex

data['messages'] = data['messages'].str.replace('[^\w\s]', ' ', regex=True)
data['messages'] = data['messages'].str.replace('\d+', '', regex=True)
data['messages'] = data['messages'].str.replace('_', ' ', regex=True)
data['messages'] = data['messages'].str.replace('\s+', ' ', regex=True)

# %%
data['messages'][9345]
# Out:
# 'On Mon at che wrote thats the correct lines to be added to sources list for the repository i just did a apt get install gnome session its still progressing Excellent might give it a bash tonight RPM List mailing list RPM List freshrpms net URL '

# %% [markdown]
# ### CountVectorizer Usage

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
out = vectorizer.fit_transform(data['messages'].astype('str'))

# %%
out.shape
# Out:
# (9348, 57736)

# %% [markdown]
# ### Sparse Matrix
# Out is a sparse matrix (mostly zeroes)
# To view it, convert to an array

# %%
out[0].toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]])

# %% [markdown]
# ### Vocab
# There is a dictionary of word to column
# Here let's find where the column 'Martin' is counted
# Since the default in CountVectorizer is to lower case everything
# Martin, martin, MaRtiN are all counted as 'martin'

# %%
vectorizer.vocabulary_
# Out:
# {'dear': 11218,
#  'homeowner': 21665,
#  'interest': 23889,
#  'rates': 39004,
#  'are': 2489,
#  'at': 2927,
#  'their': 47606,
#  'lowest': 28190,
#  'point': 36495,
#  'in': 23033,
#  'years': 53907,
#  'we': 52178,
#  'help': 21092,
#  'you': 54095,
#  'find': 17173,
#  'the': 47571,
#  'best': 4424,
#  'rate': 39001,
#  'for': 17711,
#  'your': 54111,
#  'situation': 43647,
#  'by': 6405,
#  'matching': 29193,
#  'needs': 31852,
#  'with': 52886,
#  'hundreds': 22084,
#  'of': 33310,
#  'lenders': 27188,
#  'home': 21647,
#  'improvement': 23018,
#  'refinance': 39585,
#  'second': 42456,
#  'mortgage': 30895,
#  'equity': 15419,
#  'loans': 27892,
#  'and': 1798,
#  'more': 30840,
#  'even': 15820,
#  'less': 27239,
#  'than': 47545,
#  'perfect': 35396,
#  'credit': 10220,
#  'this': 47760,
#  'service': 42800,
#  'is': 24369,
#  'free': 18101,
#  'to': 48183,
#  'owners': 34396,
#  'new': 32109,
#  'buyers': 6321,
#  'without': 52901,
#  'any': 2135,
#  'obligation': 33108,
#  'just': 25474,
#  'fill': 17117,
#  'out': 34126,
#  'quick': 38570,
#  'simple': 43517,
#  'form': 17819,
#  'jump': 25428,
#  'start': 45222,
#  'future': 18525,
#  'plans': 36233,
#  'today': 48203,
#  'visit': 51404,
#  'url': 50460,
#  'unsubscribe': 50237,
#  'please': 36306,
#  'backup': 3596,
#  'dvd': 13959,
#  'dvdcopyplus': 13962,
#  'powercdr': 36896,
#  'can': 6695,
#  'copy': 9759,
#  'burn': 6220,
#  'movies': 31013,
#  'playstation': 36292,
#  'mps': 31057,
#  'avis': 3341,
#  'all': 1401,
#  'other': 34064,
#  'multimedia': 31237,
#  'files': 17100,
#  'software': 44286,
#  'music': 31331,
#  'cds': 7242,
#  'raw': 39045,
#  'data': 11014,
#  'duplication': 13918,
#  'cd': 7210,
#  'or': 33845,
#  'protect': 37766,
#  'investments': 24163,
#  'backing': 3571,
#  'up': 50327,
#  'mp': 31031,
#  'game': 18667,
#  'collections': 8672,
#  'burned': 6221,
#  'copies': 9749,
#  'that': 47557,
#  'really': 39200,
#  'work': 53060,
#  'separately': 42714,
#  'over': 34237,
#  'worth': 53138,
#  'purchase': 38093,
#  'bundled': 6166,
#  'right': 40790,
#  'now': 32775,
#  'off': 33322,
#  'details': 11961,
#  'order': 33880,
#  'take': 46822,
#  'privacy': 37384,
#  'very': 51098,
#  'seriously': 42771,
#  'it': 24498,
#  'our': 34113,
#  'policy': 36535,
#  'never': 32098,
#  'send': 42660,
#  'unwanted': 50297,
#  'email': 14780,
#  'messages': 29830,
#  'message': 29825,
#  'has': 20754,
#  'been': 4165,
#  'sent': 42698,
#  'zzzz': 54807,
#  'example': 15934,
#  'com': 8751,
#  'because': 4125,
#  'originally': 33952,
#  'joined': 25209,
#  'one': 33593,
#  'member': 29688,
#  'sites': 43637,
#  'signed': 43429,
#  'party': 34880,
#  'contracted': 9599,
#  'atomicdot': 2980,
#  'click': 8289,
#  'here': 21169,
#  'replying': 40126,
#  'will': 52710,
#  'not': 32695,
#  'trck': 48763,
#  'qhwqrwhlqf': 38333,
#  'frp': 18311,
#  'guaranteed': 20178,
#  'eight': 14533,
#  'effective': 14429,
#  'yield': 54000,
#  'year': 53901,
#  'surrender': 46307,
#  'period': 35426,
#  'fax': 16718,
#  'back': 3549,
#  'contracts': 9605,
#  'insurance': 23784,
#  'license': 27439,
#  'issued': 24472,
#  'age': 984,
#  'rated': 39002,
#  'company': 8917,
#  'alternative': 1540,
#  'plan': 36213,
#  'call': 6608,
#  'information': 23426,
#  'below': 4300,
#  'name': 31590,
#  'address': 610,
#  'city': 8065,
#  'state': 45251,
#  'zip': 54524,
#  'phone': 35825,
#  'mail': 28669,
#  'don': 13163,
#  'want': 51907,
#  'anyone': 2143,
#  'receive': 39311,
#  'mailings': 28689,
#  'who': 52606,
#  'does': 13081,
#  'wish': 52875,
#  'them': 47616,
#  'professional': 37508,
#  'communication': 8887,
#  'professionals': 37512,
#  'be': 4063,
#  'removed': 39978,
#  'from': 18278,
#  'mailing': 28685,
#  'list': 27700,
#  'do': 13015,
#  'reply': 40123,
#  'instead': 23742,
#  'go': 19570,
#  'legal': 27126,
#  'notice': 32724,
#  'congratulations': 9328,
#  'get': 19116,
#  'handheld': 20576,
#  'organizer': 33926,
#  'friend': 18224,
#  'have': 20822,
#  'personal': 35520,
#  'digital': 12338,
#  'but': 6288,
#  'need': 31842,
#  'know': 26271,
#  'where': 52525,
#  'complete': 9002,
#  'organize': 33924,
#  'life': 27475,
#  'keep': 25807,
#  'track': 48551,
#  'appointments': 2310,
#  'names': 31599,
#  'numbers': 32911,
#  'modern': 30607,
#  'store': 45531,
#  'important': 22975,
#  'text': 47476,
#  'notes': 32715,
#  'features': 16798,
#  'easy': 14165,
#  'use': 50487,
#  'touch': 48435,
#  'screen': 42273,
#  'technology': 47139,
#  'digit': 12335,
#  'calculator': 6581,
#  'currency': 10599,
#  'metric': 29896,
#  'converters': 9678,
#  'alarm': 1292,
#  'clock': 8352,
#  'password': 34918,
#  'protection': 37769,
#  'plus': 36400,
#  'try': 49013,
#  'money': 30724,
#  'saving': 41937,
#  'benefits': 4323,
#  'days': 11094,
#  'act': 489,
#  'also': 1523,
#  'full': 18430,
#  'subscription': 45897,
#  'magazine': 28607,
#  'no': 32459,
#  'additional': 601,
#  'cost': 9879,
#  'offer': 33339,
#  'risk': 40851,
#  'registration': 39696,
#  'only': 33617,
#  'takes': 46831,
#  'minute': 30280,
#  'completely': 9004,
#  'secure': 42489,
#  'satisfaction': 41887,
#  'credibility': 10217,
#  'on': 33585,
#  'line': 27600,
#  'valid': 50748,
#  'next': 32182,
#  'hours': 21882,
#  'so': 44210,
#  'copyright': 9767,
#  'american': 1637,
#  'homeowners': 21666,
#  'association': 2849,
#  'aha': 1082,
#  'rights': 40796,
#  'reserved': 40275,
#  'receiving': 39320,
#  'sendgreatoffers': 42665,
#  'subscribed': 45891,
#  'as': 2691,
#  'jm': 25099,
#  'netnoteinc': 32022,
#  'remove': 39976,
#  'subject': 45847,
#  'must': 31354,
#  'include': 23105,
#  'body': 5217,
#  'unsubscribed': 50239,
#  'correspondence': 9839,
#  'about': 209,
#  'products': 37493,
#  'services': 42802,
#  'should': 43232,
#  'directed': 12449,
#  'ad': 551,
#  'em': 14775,
#  'attention': 3032,
#  'computer': 9089,
#  'users': 50513,
#  'special': 44675,
#  'package': 34500,
#  'deal': 11201,
#  'norton': 32670,
#  'systemworks': 46698,
#  'suite': 46058,
#  'edition': 14336,
#  'includes': 23108,
#  'six': 43658,
#  'yes': 53942,
#  'feature': 16795,
#  'packed': 34507,
#  'utilities': 50584,
#  'low': 28179,
#  'price': 37299,
#  'hazardous': 20865,
#  'viruses': 51382,
#  'private': 37386,
#  'valuable': 50769,
#  'allow': 1452,
#  'transfer': 48641,
#  'mails': 28700,
#  'safely': 41632,
#  'easily': 14154,
#  'improve': 23016,
#  'pc': 35083,
#  'performance': 35407,
#  'superior': 46171,
#  'integral': 23804,
#  'diagnostics': 12179,
#  'great': 19939,
#  'combined': 8764,
#  'retail': 40454,
#  'value': 50773,
#  'yours': 54128,
#  'shipping': 43138,
#  'fall': 16530,
#  'prey': 37294,
#  'destructive': 11947,
#  'hackers': 20433,
#  'delay': 11548,
#  'screened': 42274,
#  'filtered': 17138,
#  'house': 21884,
#  'opt': 33787,
#  'system': 46689,
#  'compliance': 9016,
#  'laws': 26937,
#  'if': 22555,
#  'well': 52401,
#  'lists': 27733,
#  'thousands': 47807,
#  'providers': 37818,
#  'consantly': 9387,
#  'being': 4232,
#  'bombarded': 5287,
#  'called': 6617,
#  'making': 28776,
#  'systems': 46694,
#  'teases': 47099,
#  'limited': 27570,
#  'when': 52521,
#  'said': 41653,
#  'done': 13176,
#  'blind': 4955,
#  'sides': 43365,
#  'demanding': 11636,
#  'card': 6865,
#  'upfront': 50342,
#  'some': 44367,
#  'slick': 43886,
#  'way': 52067,
#  'after': 959,
#  'fact': 16446,
#  'too': 48316,
#  'was': 51991,
#  'skeptical': 43716,
#  'such': 45985,
#  'offers': 33345,
#  'internet': 23952,
#  'general': 18952,
#  'its': 24540,
#  'hype': 22197,
#  'probably': 37415,
#  'fortunate': 17890,
#  'me': 29502,
#  'my': 31428,
#  'main': 28721,
#  'business': 6257,
#  'slowed': 43949,
#  'down': 13317,
#  'self': 42612,
#  'employed': 14909,
#  'looked': 28060,
#  'something': 44386,
#  'fit': 17294,
#  'lifestyle': 27489,
#  'assist': 2834,
#  'paying': 35043,
#  'bills': 4657,
#  'working': 53079,
#  'myself': 31462,
#  'death': 11222,
#  'loosing': 28098,
#  'then': 47628,
#  'proposal': 37709,
#  'investment': 24162,
#  'had': 20448,
#  'none': 32562,
#  'interested': 23890,
#  'link': 27630,
#  'provided': 37815,
#  'regret': 39708,
#  'did': 12248,
#  'am': 1583,
#  'happy': 20648,
#  'enough': 15164,
#  'recommend': 39383,
#  'true': 48968,
#  'word': 53046,
#  'mean': 29510,
#  'absolutely': 240,
#  'join': 25208,
#  'make': 28760,
#  'results': 40435,
#  'time': 47996,
#  'efforts': 14453,
#  'instantly': 23741,
#  'updated': 50337,
#  'daily': 10871,
#  'especially': 15610,
#  'liked': 27528,
#  'idea': 22445,
#  'control': 9641,
#  'real': 39174,
#  'staying': 45298,
#  'informed': 23438,
#  'statistics': 45278,
#  'quite': 38616,
#  'simply': 43532,
#  'most': 30917,
#  'logical': 27995,
#  'opened': 33686,
#  'fair': 16501,
#  'others': 34068,
#  've': 50910,
#  'seen': 42546,
#  'before': 4180,
#  'why': 52641,
#  'specific': 44692,
#  'facts': 16459,
#  'consider': 9417,
#  'teasing': 47100,
#  'grand': 19854,
#  'testimonies': 47445,
#  'kidding': 26014,
#  'unlike': 50067,
#  'programs': 37574,
#  'give': 19315,
#  'overall': 34239,
#  'first': 17266,
#  'forking': 17812,
#  'worst': 53135,
#  'yet': 53948,
#  'joining': 25210,
#  'finding': 17180,
#  'late': 26848,
#  'wasting': 52014,
#  'trying': 49016,
#  'figure': 17074,
#  'straightforward': 45577,
#  'informative': 23437,
#  'providing': 37820,
#  'two': 49269,
#  'things': 47728,
#  'what': 52490,
#  'how': 21899,
#  'these': 47684,
#  'ultimate': 49585,
#  'makers': 28771,
#  'breakers': 5699,
#  'immediately': 22871,
#  'disclosed': 12552,
#  'discovering': 12579,
#  'maybe': 29305,
#  'hooked': 21742,
#  'locked': 27940,
#  'into': 24046,
#  'frustrating': 18332,
#  'battle': 3959,
#  'platinum': 36262,
#  'choice': 7849,
#  'stands': 45176,
#  'alone': 1489,
#  'totally': 48426,
#  'different': 12290,
#  'previously': 37291,
#  'misleading': 30358,
#  'hook': 21740,
#  'promise': 37629,
#  'lofty': 27975,
#  'mega': 29622,
#  'jackpots': 24691,
#  'own': 34392,
#  'pockets': 36466,
#  'headlines': 20939,
#  'every': 15841,
#  'week': 52329,
#  'yeah': 53900,
#  'millions': 30161,
#  'whole': 52615,
#  'thing': 47725,
#  'launched': 26896,
#  'few': 16953,
#  'weeks': 52338,
#  'ago': 1038,
#  'earnings': 14138,
#  'far': 16605,
#  'tell': 47263,
#  'wouldn': 53147,
#  'able': 169,
#  'anything': 2149,
#  'corporate': 9813,
#  'which': 52540,
#  'unusually': 50289,
#  'thorough': 47791,
#  'timely': 48004,
#  'motivating': 30940,
#  'see': 42521,
#  'action': 497,
#  'yourself': 54129,
#  'mind': 30200,
#  'site': 43628,
#  'soon': 44429,
#  'minutes': 30281,
#  'ready': 39167,
#  'whether': 52537,
#  'decent': 11294,
#  'explosive': 16219,
#  'potential': 36850,
#  'fully': 18436,
#  'loaded': 27883,
#  'hi': 21290,
#  'tech': 47107,
#  'support': 46229,
#  'protective': 37771,
#  'safeguards': 41626,
#  'questions': 38557,
#  'could': 9912,
#  'like': 27526,
#  'helping': 21100,
#  'finally': 17153,
#  'pay': 35031,
#  'good': 19658,
#  'luck': 28305,
#  'ben': 4305,
#  'green': 19957,
#  'pop': 36651,
#  'ofered': 33321,
#  'members': 29689,
#  'dare': 10972,
#  'better': 4461,
#  'annuity': 1969,
#  'deposits': 11777,
#  'totalling': 48425,
#  'sex': 42875,
#  'drive': 13690,
#  'viagra': 51175,
#  'online': 33614,
#  'shipped': 43135,
#  'within': 52898,
#  'stay': 45296,
#  'hard': 20666,
#  'once': 33589,
#  'per': 35374,
#  'dose': 13259,
#  'happen': 20638,
#  'again': 977,
#  'settle': 42840,
#  'lover': 28170,
#  'doctor': 13045,
#  'office': 33350,
#  'write': 53215,
#  'prescription': 37196,
#  'major': 28753,
#  'drugs': 13747,
#  'strongly': 45717,
#  'against': 979,
#  'sending': 42666,
#  'unsolicited': 50220,
#  'emails': 14796,
#  'those': 47798,
#  'opted': 33789,
#  'affiliate': 900,
#  'requesting': 40209,
#  'notified': 32735,
#  'may': 29303,
#  'run': 41410,
#  'attained': 3010,
#  'an': 1742,
#  'independent': 23208,
#  'rd': 39102,
#  'overlook': 34292,
#  'management': 28835,
#  'removal': 39974,
#  'further': 18501,
#  'accept': 309,
#  'apologies': 2226,
#  'error': 15520,
#  'honor': 21724,
#  'requests': 40210,
#  'domain': 13130,
#  'available': 3290,
#  'public': 37989,
#  'discount': 12566,
#  'prices': 37304,
#  'register': 39689,
#  'exciting': 15989,
#  'biz': 4791,
#  'info': 23396,
#  'original': 33949,
#  'net': 31970,
#  'brand': 5643,
#  'extensions': 16276,
#  'were': 52434,
#  'recently': 39323,
#  'approved': 2349,
#  'icann': 22354,
#  'same': 41737,
#  'biggest': 4597,
#  'benefit': 4320,
#  'course': 9983,
#  'currently': 10603,
#  'much': 31162,
#  'easier': 14151,
#  'attractive': 3056,
#  'remember': 39940,
#  'fees': 16842,
#  'access': 321,
#  'panel': 34650,
#  'manage': 28831,
#  'sincerely': 43556,
#  'administrator': 687,
#  'affordable': 921,
#  'domains': 13139,
#  'promotional': 37641,
#  'ss': 45059,
#  'oxer': 34412,
#  'uqkhkcdl': 50411,
#  'geil': 18924,
#  'publishing': 38006,
#  'tools': 48328,
#  'alert': 1344,
#  'publish': 38001,
#  'create': 10196,
#  'ebooks': 14201,
#  'ebrochures': 14204,
#  'ecatalogs': 14221,
#  'resumes': 40447,
#  'newsletters': 32153,
#  'presentations': 37204,
#  'magazines': 28609,
#  'photo': 35843,
#  'albums': 1323,
#  'invitations': 24174,
#  'save': 41926,
#  'trees': 48796,
#  'printing': 37359,
#  'postage': 36792,
#  'advertising': 805,
#  'costs': 9889,
#  'download': 13330,
#  'version': 51074,
#  'choose': 7864,
#  'display': 12704,
#  'styles': 45802,
#  'page': 34537,
#  'turn': 49157,
#  'slide': 43889,
#  'show': 43248,
#  'sweep': 46446,
#  'wipe': 52844,
#  'embed': 14816,
#  'hyperlinks': 22208,
#  'anywhere': 2154,
#  'website': 52296,
#  'contact': 9524,
#  'distribute': 12794,
#  'via': 51170,
#  'floppy': 17510,
#  'rom': 41071,
#  'marketing': 29048,
#  'level': 27273,
#  'samples': 41751,
#  'appropriate': 2341,
#  'server': 42786,
#  'demand': 11633,
#  'extremely': 16328,
#  'high': 21320,
#  'links': 27646,
#  'periodically': 35428,
#  'seems': 42544,
#  'slow': 43946,
#  'unreachable': 50153,
#  'cick': 7970,
#  'button': 6309,
#  'id': 22422,
#  'functional': 18449,
#  'expiration': 16180,
#  'spread': 44926,
#  'limit': 27566,
#  'sale': 41682,
#  'three': 47822,
#  'commission': 8843,
#  'streams': 45637,
#  'agent': 996,
#  'client': 8300,
#  'old': 33485,
#  'male': 28791,
#  'female': 16874,
#  'result': 40425,
#  'die': 12255,
#  'minimal': 30237,
#  'cash': 6995,
#  'longer': 28044,
#  'required': 40212,
#  'insured': 23787,
#  'utilized': 50591,
#  'settlement': 42842,
#  'received': 39312,
#  'health': 20962,
#  'complications': 9021,
#  'small': 43981,
#  'annual': 1965,
#  'premium': 37150,
#  'expires': 16183,
#  'multiple': 31249,
#  'opportunities': 33765,
#  'earn': 14130,
#  'commissions': 8849,
#  'strategy': 45611,
#  'elderly': 14632,
#  'financial': 17160,
#  'circumstances': 8025,
#  'changed': 7522,
#  'since': 43553,
#  'opportunity': 33766,
#  'income': 23117,
#  'stream': 45628,
#  'settlements': 42843,
#  'referral': 39571,
#  'fee': 16825,
#  'transaction': 48630,
#  'trailer': 48596,
#  'record': 39410,
#  'capital': 6795,
#  'created': 10197,
#  'suit': 46052,
#  'current': 10600,
#  'conversion': 9673,
#  'considered': 9424,
#  'term': 47367,
#  'product': 37485,
#  'referring': 39576,
#  'agents': 997,
#  'agencies': 990,
#  'alliance': 1433,
#  'bottom': 5486,
#  'away': 3381,
#  'people': 35357,
#  'month': 30784,
#  'let': 27251,
#  'talk': 46850,
#  'think': 47731,
#  'earned': 14131,
#  'precisely': 37039,
#  'doing': 13106,
#  'scanned': 42018,
#  'checks': 7675,
#  'eyes': 16363,
#  'tweaked': 49227,
#  'little': 27766,
#  'busy': 6281,
#  'aren': 2497,
#  'talking': 46857,
#  'us': 50473,
#  'helped': 21094,
#  'julie': 25420,
#  'jeff': 24903,
#  'exact': 15914,
#  'exactly': 15915,
#  'expect': 16133,
#  're': 39124,
#  'starting': 45229,
#  'guesswork': 20208,
#  'evaluate': 15798,
#  'would': 53146,
#  'fly': 17561,
#  'los': 28119,
#  'angeles': 1864,
#  'expense': 16154,
#  'closer': 8375,
#  'look': 28058,
#  'following': 17655,
#  'postal': 36793,
#  'number': 32908,
#  'area': 2490,
#  'code': 8554,
#  'mailto': 28714,
#  'cashflows': 7001,
#  'excite': 15985,
#  'senate': 42656,
#  'bill': 4641,
#  'title': 48085,
#  'section': 42480,
#  'states': 45261,
#  'statement': 45258,
#  'transmissions': 48693,
#  'commercial': 8831,
#  'electronic': 14666,
#  'recipient': 39349,
#  'person': 35518,
#  'initiates': 23544,
#  'transmission': 48692,
#  'stopped': 45524,
#  'originating': 33957,
#  'hottest': 21870,
#  'dvds': 13969,
#  'onto': 33637,
#  'hot': 21847,
#  'through': 47849,
#  'steps': 45372,
#  'included': 23106,
#  'step': 45360,
#  'interactive': 23859,
#  'instructions': 23763,
#  'burner': 6222,
#  'live': 27771,
#  'technical': 47118,
#  'day': 11082,
#  'trial': 48825,
#  'movie': 31009,
#  'zkzm': 54560,
#  'blanzxad': 4895,
#  'bmnttico': 5134,
#  'rikgl': 40809,
#  'extended': 16269,
#  'auto': 3203,
#  'warranty': 51974,
#  'car': 6843,
#  'quote': 38637,
#  'troubles': 48941,
#  'always': 1573,
#  'seem': 42540,
#  'possible': 36785,
#  'family': 16565,
#  'quality': 38481,
#  'truck': 48961,
#  'suv': 46363,
#  'large': 26806,
#  'cannot': 6747,
#  'hit': 21452,
#  'cover': 10007,
#  'vehicles': 50932,
#  'miles': 30129,
#  'buy': 6318,
#  'direct': 12447,
#  'prompt': 37645,
#  'toll': 48254,
#  'claims': 8141,
#  'hour': 21880,
#  'roadside': 40957,
#  'assistance': 2835,
#  'rental': 40052,
#  'trip': 48883,
#  'interruption': 23990,
#  'intervention': 24016,
#  'towing': 48478,
#  'definitely': 11485,
#  'answer': 2012,
#  'waiting': 51824,
#  'awhile': 3398,
#  'comes': 8783,
#  'along': 1490,
#  'involved': 24193,
#  'gut': 20278,
#  'feeling': 16836,
#  'going': 19616,
#  'huge': 22018,
#  'hope': 21761,
#  'rests': 40421,
#  'deep': 11405,
#  'bones': 5315,
#  'overly': 34295,
#  'excited': 15986,
#  'scream': 42266,
#  'world': 53101,
#  'writing': 53225,
#  'although': 1546,
#  'program': 37552,
#  'launching': 26899,
#  'big': 4588,
#  'advertised': 798,
#  'promoted': 37636,
#  'everywhere': 15854,
#  'early': 14129,
#  'masses': 29168,
#  'traditionally': 48584,
#  'there': 47658,
#  'couple': 9966,
#  'flaws': 17420,
#  'mlm': 30502,
#  'multi': 31216,
#  'newcomers': 32121,
#  'made': 28585,
#  'difficult': 12305,
#  'last': 26836,
#  'initial': 23532,
#  'hoopla': 21750,
#  'solution': 44349,
#  'problems': 37428,
#  'newest': 32124,
#  'innovative': 23608,
#  'ever': 15832,
#  'ingenious': 23488,
#  'payplan': 35056,
#  'payout': 35052,
#  'everyone': 15849,
#  'winner': 52816,
#  'truth': 49002,
#  'got': 19716,
#  'believe': 4264,
#  'rather': 39006,
#  'feed': 16826,
#  'lot': 28129,
#  'miracle': 30293,
#  'looking': 28064,
#  'magic': 28615,
#  'end': 15009,
#  'hear': 20970,
#  'itshappening': 24544,
#  'mailworld': 28719,
#  'provide': 37814,
#  'test': 47426,
#  'birds': 4731,
#  'eye': 16352,
#  'inside': 23666,
#  'revealing': 40549,
#  'inner': 23593,
#  'workings': 53080,
#  'revolutionary': 40612,
#  'discovery': 12581,
#  'decide': 11304,
#  'option': 33822,
#  'activating': 507,
#  'position': 36762,
#  'isn': 24441,
#  'trick': 48843,
#  'convinced': 9692,
#  'sound': 44483,
#  'unique': 50009,
#  'solid': 44331,
#  'miss': 30371,
#  'chance': 7512,
#  'launch': 26895,
#  'positions': 36765,
#  'filling': 17123,
#  'rapidly': 38966,
#  'explore': 16211,
#  'diving': 12860,
#  'head': 20921,
#  'cautious': 7131,
#  'likes': 27536,
#  'leap': 27058,
#  'thank': 47548,
#  'discover': 12575,
#  'smiling': 44043,
#  'treat': 48776,
#  'spam': 44569,
#  'successful': 45968,
#  'networker': 32055,
#  'base': 3884,
#  'pursueded': 38128,
#  'containing': 9537,
#  'individuals': 23280,
#  'given': 19319,
#  'consent': 9401,
#  'used': 50491,
#  'means': 29517,
#  'frankly': 18055,
#  'dubious': 13827,
#  'validity': 50755,
#  'however': 21909,
#  'having': 20836,
#  'spent': 44764,
#  'arm': 2559,
#  'leg': 27123,
#  'purchasing': 38098,
#  'initially': 23539,
#  ...}

# %%
vectorizer.vocabulary_['handheld']
# Out:
# 20576

# %% [markdown]
# #### How to reverse a dictionary
# and translate back and forth between vector and text

# %%
reverse = {value:key for key,value in vectorizer.vocabulary_.items()}

# %%
out[0].toarray()[:,32941]
# Out:
# array([0])

# %% [markdown]
# Compare these two, Notice what CountVectorizer did and did not include

# %%
for i in range(57736):
    if out[0].toarray()[:,i]!=0:
        print(reverse[i],out[0].toarray()[:,i])
# Out:
# and [3]
# any [1]
# are [1]
# at [1]
# best [1]
# buyers [1]
# by [1]
# credit [1]
# dear [1]
# equity [1]
# even [1]
# fill [1]
# find [1]
# for [1]
# form [1]
# free [1]
# future [1]
# help [1]
# home [4]
# homeowner [1]
# hundreds [1]
# improvement [1]
# in [1]
# interest [1]
# is [1]
# jump [1]
# just [1]
# lenders [1]
# less [1]
# loans [1]
# lowest [1]
# matching [1]
# more [1]
# mortgage [1]
# needs [1]
# new [1]
# obligation [1]
# of [1]
# out [1]
# owners [1]
# perfect [1]
# plans [1]
# please [1]
# point [1]
# quick [1]
# rate [1]
# rates [1]
# refinance [1]
# second [1]
# service [1]
# simple [1]
# situation [1]
# start [1]
# than [1]
# the [1]
# their [1]
# this [1]
# to [2]
# today [1]
# unsubscribe [1]
# url [2]
# visit [2]
# we [1]
# with [2]
# without [1]
# years [1]
# you [1]
# your [3]

# %%
## Add Target
targets = data['Target']

# %%
from sklearn.naive_bayes import MultinomialNB

model= MultinomialNB(alpha=0.1)

# %%
# Evaluate the model using cross-validation
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, precision_score, recall_score, accuracy_score

scores = cross_val_score(model, out, targets, cv=10)

# Calculate precision score using cross-validation
precision_scorer = make_scorer(precision_score, pos_label=1)
precision_cv = cross_val_score(model, out, targets, cv=10, scoring=precision_scorer)
precision = np.mean(precision_cv) # Take the mean of the scores to obtain a single estimate of the precision

# Print the mean and standard deviation of the cross-validation scores
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
print("Precision: %.2f" % precision)
# Out:
# Accuracy: 0.98 (+/- 0.08)
# Precision: 0.96

# %%
# Evaluate the model using cross-validation

from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, precision_score, recall_score, accuracy_score

scores = cross_val_score(model, out, targets, cv=10)

# Calculate precision score using cross-validation
precision_scorer = make_scorer(precision_score, pos_label=1)
precision_cv = cross_val_score(model, out, targets, cv=10, scoring=precision_scorer)
precision = np.mean(precision_cv) # Take the mean of the scores to obtain a single estimate of the precision

# Calculate recall score using cross-validation
recall_scorer = make_scorer(recall_score, pos_label=1)
recall_cv = cross_val_score(model, out, targets, cv=10, scoring=recall_scorer)
recall = np.mean(recall_cv) # Take the mean of the scores to obtain a single estimate of the recall

# Print the mean and standard deviation of the cross-validation scores
print("Accuracy: %0.4f (+/- %0.4f)" % (scores.mean(), scores.std() * 2))
print("Precision: %.4f" % precision)
print("Specificity: %.4f" % recall)
# Out:
# Accuracy: 0.9753 (+/- 0.0786)
# Precision: 0.9592
# Specificity: 0.9620
