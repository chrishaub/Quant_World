# %%
import pandas as pd
import numpy as np
import os
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
import statistics
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV
import xgboost as xgb

# %%
# import graphviz

# %%
loc = '/Users/alonsosalcido/Desktop/Quantifying the World/case 4/data'

# %%
year1 = pd.read_csv("D:\\SMUMSDS\\QuantWorld\\CS4\\1year.arff",skiprows=69,header=None,na_values='?')
year2 = pd.read_csv("D:\\SMUMSDS\\QuantWorld\\CS4\\2year.arff",skiprows=69,header=None,na_values='?')
year3 = pd.read_csv("D:\\SMUMSDS\\QuantWorld\\CS4\\3year.arff",skiprows=69,header=None,na_values='?')
year4 = pd.read_csv("D:\\SMUMSDS\\QuantWorld\\CS4\\4year.arff",skiprows=69,header=None,na_values='?')
year5 = pd.read_csv("D:\\SMUMSDS\\QuantWorld\\CS4\\5year.arff",skiprows=69,header=None,na_values='?')
data_labels=pd.read_csv('https://raw.githubusercontent.com/AlonsoSalcido/Quantifying-the-World/main/Data_Labels.csv')
count = 1
for i in [year1,year2,year3,year4,year5]:
    i['year']=count
    count+=1

# %%
# Concatenate Tables
data = pd.concat([year1,year2,year3,year4,year5],axis=0,ignore_index=True)
data.columns = data.columns.astype(str)

# %%
# Display Data Info with classes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43405 entries, 0 to 43404
# Data columns (total 66 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       43397 non-null  float64
#  1   1       43397 non-null  float64
#  2   2       43397 non-null  float64
#  3   3       43271 non-null  float64
#  4   4       43316 non-null  float64
#  5   5       43397 non-null  float64
#  6   6       43397 non-null  float64
#  7   7       43311 non-null  float64
#  8   8       43396 non-null  float64
#  9   9       43397 non-null  float64
#  10  10      43361 non-null  float64
#  11  11      43271 non-null  float64
#  12  12      43278 non-null  float64
#  13  13      43397 non-null  float64
#  14  14      43369 non-null  float64
#  15  15      43310 non-null  float64
#  16  16      43311 non-null  float64
#  17  17      43397 non-null  float64
#  18  18      43277 non-null  float64
#  19  19      43278 non-null  float64
#  20  20      37551 non-null  float64
#  21  21      43397 non-null  float64
#  22  22      43278 non-null  float64
#  23  23      42483 non-null  float64
#  24  24      43397 non-null  float64
#  25  25      43310 non-null  float64
#  26  26      40641 non-null  float64
#  27  27      42593 non-null  float64
#  28  28      43397 non-null  float64
#  29  29      43278 non-null  float64
#  30  30      43278 non-null  float64
#  31  31      43037 non-null  float64
#  32  32      43271 non-null  float64
#  33  33      43311 non-null  float64
#  34  34      43397 non-null  float64
#  35  35      43397 non-null  float64
#  36  36      24421 non-null  float64
#  37  37      43397 non-null  float64
#  38  38      43278 non-null  float64
#  39  39      43271 non-null  float64
#  40  40      42651 non-null  float64
#  41  41      43278 non-null  float64
#  42  42      43278 non-null  float64
#  43  43      43278 non-null  float64
#  44  44      41258 non-null  float64
#  45  45      43270 non-null  float64
#  46  46      43108 non-null  float64
#  47  47      43396 non-null  float64
#  48  48      43278 non-null  float64
#  49  49      43311 non-null  float64
#  50  50      43397 non-null  float64
#  51  51      43104 non-null  float64
#  52  52      42593 non-null  float64
#  53  53      42593 non-null  float64
#  54  54      43404 non-null  float64
#  55  55      43278 non-null  float64
#  56  56      43398 non-null  float64
#  57  57      43321 non-null  float64
#  58  58      43398 non-null  float64
#  59  59      41253 non-null  float64
#  60  60      43303 non-null  float64
#  61  61      43278 non-null  float64
#  62  62      43271 non-null  float64
#  63  63      42593 non-null  float64
#  64  64      43405 non-null  int64
#  65  year    43405 non-null  int64
# dtypes: float64(64), int64(2)
# memory usage: 21.9 MB

# %%
data.head
# Out:
# <bound method NDFrame.head of               0        1         2        3         4        5         6  \
# 0      0.200550  0.37951  0.396410  2.04720   32.3510  0.38825  0.249760
# 1      0.209120  0.49988  0.472250  1.94470   14.7860  0.00000  0.258340
# 2      0.248660  0.69592  0.267130  1.55480   -1.1523  0.00000  0.309060
# 3      0.081483  0.30734  0.458790  2.49280   51.9520  0.14988  0.092704
# 4      0.187320  0.61323  0.229600  1.40630   -7.3128  0.18732  0.187320
# ...         ...      ...       ...      ...       ...      ...       ...
# 43400  0.012898  0.70621  0.038857  1.17220  -18.9070  0.00000  0.013981
# 43401 -0.578050  0.96702 -0.800850  0.16576  -67.3650 -0.57805 -0.578050
# 43402 -0.179050  1.25530 -0.275990  0.74554 -120.4400 -0.17905 -0.154930
# 43403 -0.108860  0.74394  0.015449  1.08780  -17.0030 -0.10886 -0.109180
# 43404 -0.105370  0.53629 -0.045578  0.91478  -56.0680 -0.10537 -0.109940
#
#              7        8         9  ...        56       57        58        59  \
# 0      1.33050  1.13890  0.504940  ...  0.397180  0.87804  0.001924    8.4160
# 1      0.99601  1.69960  0.497880  ...  0.420020  0.85300  0.000000    4.1486
# 2      0.43695  1.30900  0.304080  ...  0.817740  0.76599  0.694840    4.9909
# 3      1.86610  1.05710  0.573530  ...  0.142070  0.94598  0.000000    4.5746
# 4      0.63070  1.15590  0.386770  ...  0.484310  0.86515  0.124440    6.3985
# ...        ...      ...       ...  ...       ...      ...       ...       ...
# 43400  0.41600  1.67680  0.293790  ...  0.043904  1.01220  1.259400   13.4720
# 43401 -0.40334  0.93979 -0.390040  ...  1.482000  1.06410 -0.018084  110.7200
# 43402 -0.26018  1.17490 -0.326590  ...  0.548240  0.85112 -0.522430    9.8526
# 43403  0.12531  0.84516  0.093224  ... -1.167700  1.18320  6.092400   13.8860
# 43404  0.86460  0.95040  0.463670  ... -0.227250  1.05220  0.003196    7.7332
#
#             60       61      62        63  64  year
# 0       5.1372   82.658  4.4158   7.42770   0     1
# 1       3.2732  107.350  3.4000  60.98700   0     1
# 2       3.9510  134.270  2.7185   5.20780   0     1
# 3       3.6147   86.435  4.2228   5.54970   0     1
# 4       4.3158  127.210  2.8692   7.89800   0     1
# ...        ...      ...     ...       ...  ..   ...
# 43400  12.4320   49.117  7.4313   2.27990   1     5
# 43401  44.7590   81.220  4.4940   5.13050   1     5
# 43402   3.4892  207.870  1.7559   9.95270   1     5
# 43403   6.0769   83.122  4.3911   0.95575   1     5
# 43404   4.7174  136.850  2.6672   2.79270   1     5
#
# [43405 rows x 66 columns]>

# %%
#Column 64 should be Boolean
data['64'] = data['64'].astype('bool')

# %% [markdown]
# ## MIssing Values

# %%
# Print Data Shape
data.shape
# Out:
# (43405, 66)

# %%
# Calculate the percentage of null values in each column
null_percentages = data.isnull().sum() / len(data) * 100

# Plot the null value percentages
plt.figure(figsize=(20, 10))
plt.bar(null_percentages.index, null_percentages.values)
plt.xticks(rotation=90)
plt.xlabel('Column')
plt.ylabel('Percentage of null values')
plt.title('Percentage of null values in the dataset')
plt.show()

# %%
print(data_labels.head(60))
# Out:
#      ID                                        Description
# 0    X1                          net profit / total assets
# 1    X2                   total liabilities / total assets
# 2    X3                     working capital / total assets
# 3    X4            current assets / short-term liabilities
# 4    X5  [(cash + short-term securities + receivables -...
# 5    X6                   retained earnings / total assets
# 6    X7                                EBIT / total assets
# 7    X8           book value of equity / total liabilities
# 8    X9                               sales / total assets
# 9   X10                              equity / total assets
# 10  X11  (gross profit + extraordinary items + financia...
# 11  X12              gross profit / short-term liabilities
# 12  X13              (gross profit + depreciation) / sales
# 13  X14           (gross profit + interest) / total assets
# 14  X15  (total liabilities * 365) / (gross profit + de...
# 15  X16  (gross profit + depreciation) / total liabilities
# 16  X17                   total assets / total liabilities
# 17  X18                        gross profit / total assets
# 18  X19                               gross profit / sales
# 19  X20                          (inventory * 365) / sales
# 20  X21                            sales (n) / sales (n-1)
# 21  X22      profit on operating activities / total assets
# 22  X23                                 net profit / sales
# 23  X24           gross profit (in 3 years) / total assets
# 24  X25            (equity - share capital) / total assets
# 25  X26    (net profit + depreciation) / total liabilities
# 26  X27  profit on operating activities / financial exp...
# 27  X28                     working capital / fixed assets
# 28  X29                          logarithm of total assets
# 29  X30                 (total liabilities - cash) / sales
# 30  X31                  (gross profit + interest) / sales
# 31  X32  (current liabilities * 365) / cost of products...
# 32  X33        operating expenses / short-term liabilities
# 33  X34             operating expenses / total liabilities
# 34  X35                     profit on sales / total assets
# 35  X36                         total sales / total assets
# 36  X37  (current assets - inventories) / long-term lia...
# 37  X38                    constant capital / total assets
# 38  X39                            profit on sales / sales
# 39  X40  (current assets - inventory - receivables) / s...
# 40  X41  total liabilities / ((profit on operating acti...
# 41  X42             profit on operating activities / sales
# 42  X43  rotation receivables + inventory turnover in days
# 43  X44                        (receivables * 365) / sales
# 44  X45                             net profit / inventory
# 45  X46  (current assets - inventory) / short-term liab...
# 46  X47          (inventory * 365) / cost of products sold
# 47  X48  EBITDA (profit on operating activities - depre...
# 48  X49  EBITDA (profit on operating activities - depre...
# 49  X50                 current assets / total liabilities
# 50  X51              short-term liabilities / total assets
# 51  X52  (short-term liabilities * 365) / cost of produ...
# 52  X53                              equity / fixed assets
# 53  X54                    constant capital / fixed assets
# 54  X55                                    working capital
# 55  X56            (sales - cost of products sold) / sales
# 56  X57  (current assets - inventory - short-term liabi...
# 57  X58                           total costs /total sales
# 58  X59                     long-term liabilities / equity
# 59  X60                                  sales / inventory

# %%
#Print Data Label
print(data_labels.iloc[36]['Description'])

# Print summary statistics for column 36
print(data['36'].describe())
# Out:
# (current assets - inventories) / long-term liabilities
# count     24421.000000
# mean        105.085363
# std        3058.429830
# min        -525.520000
# 25%           1.142300
# 50%           3.096300
# 75%          11.414000
# max      398920.000000
# Name: 36, dtype: float64

# %%
train_data = data[data['36'].notnull()]
train_data_x= train_data.iloc[:, :64]
train_data_x= train_data_x.drop(train_data_x.columns[36], axis=1)

# %%
# Impute missing data in column '36

# Create KNN imputer object
imputer = KNNImputer(n_neighbors=4)

# Impute missing values in column '36'
imputed_y = imputer.fit_transform(data[['36']])

# Merge imputed '36' values with original dataframe
merged_df = pd.concat([train_data_x, pd.DataFrame(imputed_y, columns=['36'])], axis=1)
data['36']=merged_df['36']

# %%
# Print summary statistics for column 36
print(data['36'].describe())
# Out:
# count     43405.000000
# mean        105.085363
# std        2294.068984
# min        -525.520000
# 25%           2.485300
# 50%          47.120000
# 75%         105.085363
# max      398920.000000
# Name: 36, dtype: float64

# %%
dcols=data.iloc[:, :64]
dcols=dcols.drop(dcols.columns[36], axis=1)
cols_to_use = dcols.columns

# %%
# create KNN imputer object
imputer = KNNImputer(n_neighbors=4)

# impute missing values using KNN imputer
data[cols_to_use] = imputer.fit_transform(data[cols_to_use])

# %%
#Check For Null Values After Imputation

# Count the total null values in the dataset
total_null_count = data.isnull().sum().sum()

print("Data Shape:", data.shape)
print("Total null values in the dataset:", total_null_count)
# Out:
# Data Shape: (43405, 66)
# Total null values in the dataset: 0

# %%
from sklearn.model_selection import cross_val_score, cross_val_predict, KFold
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_jobs=10)
splits = KFold(n_splits=5,shuffle=True)
cross_val_scores= cross_val_score(rf, data.iloc[:,0:64],data.iloc[:,64], cv=splits, scoring='roc_auc')
print(cross_val_scores)
# Out:
# [0.90314238 0.89205576 0.88155085 0.89785213 0.89975131]

# %% [markdown]
# ## Grid Search

# %%
# %%time

parameters = {
    'class_weight': ['balanced'],
    'criterion': ['entropy'],
    'max_depth': [15, 20, 30],
    'min_samples_split': [4,8,16],
    'min_samples_leaf':[2,4,6],
    'max_features': ['log2', 'sqrt'],
    'n_estimators': [100, 200]
}
search = RandomizedSearchCV(rf,parameters, scoring='roc_auc',cv=splits, n_iter=20)
outcomes = search.fit(data.iloc[:,0:64],data.iloc[:,64],)
# Out:
# Wall time: 16min 41s

# %%
outcomes.cv_results_
# Out:
# {'mean_fit_time': array([ 6.02964563, 12.85016766,  6.15039301,  9.9721015 , 10.10882173,
#          9.88974853,  9.60771108,  6.18368273, 12.67601743,  9.70096369,
#          8.97589979, 12.44914021, 12.9287528 , 12.50322685, 10.1835856 ,
#          5.59457345, 12.85800171, 10.40563197,  9.61037011,  6.47868476]),
#  'std_fit_time': array([0.75130286, 1.18836148, 0.47447721, 0.40960318, 0.42763291,
#         0.58113105, 0.66280959, 0.74062839, 1.52418833, 0.60386102,
#         0.58305109, 0.89055051, 0.56902565, 1.19857533, 0.5676403 ,
#         0.74493108, 0.49842436, 0.63379666, 0.85883308, 0.5486188 ]),
#  'mean_score_time': array([0.03429632, 0.08756781, 0.04370732, 0.09320421, 0.08389754,
#         0.09649348, 0.07810016, 0.05325618, 0.08965964, 0.08660216,
#         0.07497206, 0.08127375, 0.1013905 , 0.08438406, 0.10335531,
#         0.04966493, 0.08147511, 0.07818708, 0.08436837, 0.05316792]),
#  'std_score_time': array([0.00620383, 0.01623245, 0.00622157, 0.02316162, 0.01153507,
#         0.02442224, 0.00988145, 0.02134   , 0.01239862, 0.0253904 ,
#         0.01176265, 0.00623919, 0.01265281, 0.00765709, 0.02853965,
#         0.00555709, 0.00646273, 0.00988771, 0.0076591 , 0.01239552]),
#  'param_n_estimators': masked_array(data=[100, 200, 100, 200, 200, 200, 200, 100, 200, 200, 200,
#                     200, 200, 200, 200, 100, 200, 200, 200, 100],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_split': masked_array(data=[16, 4, 8, 16, 8, 4, 8, 8, 8, 4, 8, 8, 4, 16, 8, 16, 8,
#                     16, 16, 16],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[6, 6, 6, 6, 4, 2, 2, 4, 4, 6, 6, 2, 2, 4, 4, 4, 6, 2,
#                     6, 2],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=['sqrt', 'sqrt', 'sqrt', 'log2', 'log2', 'log2', 'log2',
#                     'sqrt', 'sqrt', 'log2', 'log2', 'sqrt', 'sqrt', 'sqrt',
#                     'log2', 'log2', 'sqrt', 'log2', 'log2', 'sqrt'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[30, 20, 30, 15, 15, 20, 30, 15, 20, 15, 30, 30, 15, 30,
#                     20, 20, 15, 30, 20, 30],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_criterion': masked_array(data=['entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_class_weight': masked_array(data=['balanced', 'balanced', 'balanced', 'balanced',
#                     'balanced', 'balanced', 'balanced', 'balanced',
#                     'balanced', 'balanced', 'balanced', 'balanced',
#                     'balanced', 'balanced', 'balanced', 'balanced',
#                     'balanced', 'balanced', 'balanced', 'balanced'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'n_estimators': 100,
#    'min_samples_split': 16,
#    'min_samples_leaf': 6,
#    'max_features': 'sqrt',
#    'max_depth': 30,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 200,
#    'min_samples_split': 4,
#    'min_samples_leaf': 6,
#    'max_features': 'sqrt',
#    'max_depth': 20,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 100,
#    'min_samples_split': 8,
#    'min_samples_leaf': 6,
#    'max_features': 'sqrt',
#    'max_depth': 30,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 200,
#    'min_samples_split': 16,
#    'min_samples_leaf': 6,
#    'max_features': 'log2',
#    'max_depth': 15,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 200,
#    'min_samples_split': 8,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 15,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 200,
#    'min_samples_split': 4,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': 20,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 200,
#    'min_samples_split': 8,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': 30,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 100,
#    'min_samples_split': 8,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 15,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 200,
#    'min_samples_split': 8,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 20,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 200,
#    'min_samples_split': 4,
#    'min_samples_leaf': 6,
#    'max_features': 'log2',
#    'max_depth': 15,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 200,
#    'min_samples_split': 8,
#    'min_samples_leaf': 6,
#    'max_features': 'log2',
#    'max_depth': 30,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 200,
#    'min_samples_split': 8,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': 30,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 200,
#    'min_samples_split': 4,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': 15,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 200,
#    'min_samples_split': 16,
#    'min_samples_leaf': 4,
#    'max_features': 'sqrt',
#    'max_depth': 30,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 200,
#    'min_samples_split': 8,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 20,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 100,
#    'min_samples_split': 16,
#    'min_samples_leaf': 4,
#    'max_features': 'log2',
#    'max_depth': 20,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 200,
#    'min_samples_split': 8,
#    'min_samples_leaf': 6,
#    'max_features': 'sqrt',
#    'max_depth': 15,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 200,
#    'min_samples_split': 16,
#    'min_samples_leaf': 2,
#    'max_features': 'log2',
#    'max_depth': 30,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 200,
#    'min_samples_split': 16,
#    'min_samples_leaf': 6,
#    'max_features': 'log2',
#    'max_depth': 20,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'},
#   {'n_estimators': 100,
#    'min_samples_split': 16,
#    'min_samples_leaf': 2,
#    'max_features': 'sqrt',
#    'max_depth': 30,
#    'criterion': 'entropy',
#    'class_weight': 'balanced'}],
#  'split0_test_score': array([0.91985814, 0.92229298, 0.92017082, 0.89781808, 0.9005002 ,
#         0.90747942, 0.92292788, 0.9028598 , 0.92041441, 0.90082366,
#         0.91547364, 0.92649528, 0.90044142, 0.92516345, 0.91192455,
#         0.91169896, 0.90912701, 0.9148772 , 0.91312174, 0.91842105]),
#  'split1_test_score': array([0.91532133, 0.91617265, 0.91315816, 0.89716929, 0.8961797 ,
#         0.90827734, 0.91197744, 0.89699165, 0.91732717, 0.89684625,
#         0.90881601, 0.9170328 , 0.89816508, 0.91511842, 0.9050801 ,
#         0.90242849, 0.90536594, 0.9100936 , 0.90739301, 0.91612661]),
#  'split2_test_score': array([0.90318795, 0.90486892, 0.90255906, 0.88416701, 0.88295789,
#         0.89399703, 0.90525451, 0.89549911, 0.90493602, 0.88512404,
#         0.89784443, 0.90606641, 0.89091486, 0.90778837, 0.8984092 ,
#         0.88944442, 0.89760653, 0.90174716, 0.89315478, 0.90427379]),
#  'split3_test_score': array([0.90973125, 0.90955227, 0.90451778, 0.89024567, 0.89039002,
#         0.90017299, 0.90784428, 0.90240068, 0.91055703, 0.89127137,
#         0.90520121, 0.91935591, 0.89613643, 0.91115681, 0.90665099,
#         0.89658017, 0.89725291, 0.90687301, 0.90415527, 0.91173678]),
#  'split4_test_score': array([0.91016703, 0.90957558, 0.90690679, 0.8934325 , 0.88931514,
#         0.90417707, 0.90627099, 0.89427872, 0.90879427, 0.88863328,
#         0.90452464, 0.91619656, 0.89191038, 0.91164945, 0.90407192,
#         0.90079402, 0.89860916, 0.90699163, 0.90499502, 0.90475764]),
#  'mean_test_score': array([0.91165314, 0.91249248, 0.90946252, 0.89256651, 0.89186859,
#         0.90282077, 0.91085502, 0.89840599, 0.91240578, 0.89253972,
#         0.90637198, 0.91702939, 0.89551363, 0.9141753 , 0.90522735,
#         0.90018921, 0.90159231, 0.90811652, 0.90456396, 0.91106317]),
#  'std_test_score': array([0.00562742, 0.00608055, 0.00643374, 0.00500904, 0.00601992,
#         0.00525711, 0.0064569 , 0.00355749, 0.00566774, 0.0056397 ,
#         0.00576742, 0.00657109, 0.00362859, 0.00596511, 0.00435254,
#         0.00729836, 0.00478807, 0.00431268, 0.00650786, 0.00576344]),
#  'rank_test_score': array([ 5,  3,  8, 18, 20, 13,  7, 16,  4, 19, 10,  1, 17,  2, 11, 15, 14,
#          9, 12,  6])}

# %%
outcomes.best_score_
# Out:
# 0.9170293903841843

# %%
outcomes.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 8,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 30,
#  'criterion': 'entropy',
#  'class_weight': 'balanced'}

# %% [markdown]
# ## XGBoost

# %%
Xtrain,Xtest,ytrain,ytest = train_test_split(data.iloc[:,0:64],data.iloc[:,64],test_size=0.20)

# %%
train_dm = xgb.DMatrix(Xtrain,label=ytrain)
eval_dm = xgb.DMatrix(Xtest,label=ytest)

# %%
params = {
          'max_depth': 30,
          'eval_metric':'auc',
          'objective':'binary:logistic', 
          'num_boost_round':100
         }

# %%
xgb_scores=xgb.train(params,evals=[(train_dm,'train'),(eval_dm,'test')],
            dtrain=train_dm, verbose_eval=True, num_boost_round=params['num_boost_round'])
# Out:
# [19:55:11] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "num_boost_round" } are not used.
#
# [0]	train-auc:0.85528	test-auc:0.74811
# [1]	train-auc:0.92973	test-auc:0.82102
# [2]	train-auc:0.94829	test-auc:0.83899
# [3]	train-auc:0.97258	test-auc:0.85256
# [4]	train-auc:0.98545	test-auc:0.86429
# [5]	train-auc:0.99078	test-auc:0.86922
# [6]	train-auc:0.99650	test-auc:0.87381
# [7]	train-auc:0.99779	test-auc:0.88611
# [8]	train-auc:0.99866	test-auc:0.88777
# [9]	train-auc:0.99902	test-auc:0.89272
# [10]	train-auc:0.99960	test-auc:0.89725
# [11]	train-auc:0.99986	test-auc:0.90718
# [12]	train-auc:0.99996	test-auc:0.90983
# [13]	train-auc:0.99998	test-auc:0.91236
# [14]	train-auc:0.99999	test-auc:0.91373
# [15]	train-auc:1.00000	test-auc:0.91595
# [16]	train-auc:1.00000	test-auc:0.92102
# [17]	train-auc:1.00000	test-auc:0.92509
# [18]	train-auc:1.00000	test-auc:0.92705
# [19]	train-auc:1.00000	test-auc:0.92854
# [20]	train-auc:1.00000	test-auc:0.92975
# [21]	train-auc:1.00000	test-auc:0.93041
# [22]	train-auc:1.00000	test-auc:0.92989
# [23]	train-auc:1.00000	test-auc:0.93062
# [24]	train-auc:1.00000	test-auc:0.93288
# [25]	train-auc:1.00000	test-auc:0.93389
# [26]	train-auc:1.00000	test-auc:0.93388
# [27]	train-auc:1.00000	test-auc:0.93574
# [28]	train-auc:1.00000	test-auc:0.93670
# [29]	train-auc:1.00000	test-auc:0.93769
# [30]	train-auc:1.00000	test-auc:0.93815
# [31]	train-auc:1.00000	test-auc:0.93859
# [32]	train-auc:1.00000	test-auc:0.93967
# [33]	train-auc:1.00000	test-auc:0.93998
# [34]	train-auc:1.00000	test-auc:0.94030
# [35]	train-auc:1.00000	test-auc:0.94107
# [36]	train-auc:1.00000	test-auc:0.94164
# [37]	train-auc:1.00000	test-auc:0.94226
# [38]	train-auc:1.00000	test-auc:0.94246
# [39]	train-auc:1.00000	test-auc:0.94253
# [40]	train-auc:1.00000	test-auc:0.94294
# [41]	train-auc:1.00000	test-auc:0.94393
# [42]	train-auc:1.00000	test-auc:0.94401
# [43]	train-auc:1.00000	test-auc:0.94403
# [44]	train-auc:1.00000	test-auc:0.94405
# [45]	train-auc:1.00000	test-auc:0.94438
# [46]	train-auc:1.00000	test-auc:0.94503
# [47]	train-auc:1.00000	test-auc:0.94519
# [48]	train-auc:1.00000	test-auc:0.94543
# [49]	train-auc:1.00000	test-auc:0.94562
# [50]	train-auc:1.00000	test-auc:0.94639
# [51]	train-auc:1.00000	test-auc:0.94693
# [52]	train-auc:1.00000	test-auc:0.94706
# [53]	train-auc:1.00000	test-auc:0.94725
# [54]	train-auc:1.00000	test-auc:0.94721
# [55]	train-auc:1.00000	test-auc:0.94763
# [56]	train-auc:1.00000	test-auc:0.94781
# [57]	train-auc:1.00000	test-auc:0.94823
# [58]	train-auc:1.00000	test-auc:0.94847
# [59]	train-auc:1.00000	test-auc:0.94839
# [60]	train-auc:1.00000	test-auc:0.94843
# [61]	train-auc:1.00000	test-auc:0.94850
# [62]	train-auc:1.00000	test-auc:0.94866
# [63]	train-auc:1.00000	test-auc:0.94863
# [64]	train-auc:1.00000	test-auc:0.94877
# [65]	train-auc:1.00000	test-auc:0.94885
# [66]	train-auc:1.00000	test-auc:0.94884
# [67]	train-auc:1.00000	test-auc:0.94938
# [68]	train-auc:1.00000	test-auc:0.94994
# [69]	train-auc:1.00000	test-auc:0.94999
# [70]	train-auc:1.00000	test-auc:0.95014
# [71]	train-auc:1.00000	test-auc:0.95023
# [72]	train-auc:1.00000	test-auc:0.95061
# [73]	train-auc:1.00000	test-auc:0.95054
# [74]	train-auc:1.00000	test-auc:0.95060
# [75]	train-auc:1.00000	test-auc:0.95065
# [76]	train-auc:1.00000	test-auc:0.95043
# [77]	train-auc:1.00000	test-auc:0.95063
# [78]	train-auc:1.00000	test-auc:0.95068
# [79]	train-auc:1.00000	test-auc:0.95060
# [80]	train-auc:1.00000	test-auc:0.95071
# [81]	train-auc:1.00000	test-auc:0.95073
# [82]	train-auc:1.00000	test-auc:0.95088
# [83]	train-auc:1.00000	test-auc:0.95092
# [84]	train-auc:1.00000	test-auc:0.95091
# [85]	train-auc:1.00000	test-auc:0.95109
# [86]	train-auc:1.00000	test-auc:0.95105
# [87]	train-auc:1.00000	test-auc:0.95100
# [88]	train-auc:1.00000	test-auc:0.95125
# [89]	train-auc:1.00000	test-auc:0.95124
# [90]	train-auc:1.00000	test-auc:0.95115
# [91]	train-auc:1.00000	test-auc:0.95114
# [92]	train-auc:1.00000	test-auc:0.95103
# [93]	train-auc:1.00000	test-auc:0.95113
# [94]	train-auc:1.00000	test-auc:0.95111
# [95]	train-auc:1.00000	test-auc:0.95114
# [96]	train-auc:1.00000	test-auc:0.95117
# [97]	train-auc:1.00000	test-auc:0.95112
# [98]	train-auc:1.00000	test-auc:0.95102
# [99]	train-auc:1.00000	test-auc:0.95117

# %%
# %%time
stuff=xgb.cv(params, dtrain=train_dm, nfold=5, 
       stratified=False,metrics='auc',
       num_boost_round=params['num_boost_round'],verbose_eval=True)
# Out:
# [19:55:32] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "num_boost_round" } are not used.
#
# [19:55:32] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "num_boost_round" } are not used.
#
# [19:55:32] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "num_boost_round" } are not used.
#
# [19:55:33] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "num_boost_round" } are not used.
#
# [19:55:33] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "num_boost_round" } are not used.
#
# [0]	train-auc:0.86074+0.01468	test-auc:0.78911+0.01134
# [1]	train-auc:0.92319+0.00430	test-auc:0.83448+0.01420
# [2]	train-auc:0.95720+0.00469	test-auc:0.85169+0.01277
# [3]	train-auc:0.97290+0.00303	test-auc:0.86283+0.01026
# [4]	train-auc:0.98466+0.00149	test-auc:0.86982+0.00769
# [5]	train-auc:0.99163+0.00178	test-auc:0.87624+0.00997
# [6]	train-auc:0.99577+0.00062	test-auc:0.88271+0.00888
# [7]	train-auc:0.99776+0.00078	test-auc:0.88752+0.00893
# [8]	train-auc:0.99847+0.00077	test-auc:0.89201+0.00820
# [9]	train-auc:0.99937+0.00018	test-auc:0.89534+0.00812
# [10]	train-auc:0.99971+0.00008	test-auc:0.89869+0.00702
# [11]	train-auc:0.99988+0.00002	test-auc:0.90303+0.00776
# [12]	train-auc:0.99995+0.00003	test-auc:0.90601+0.00859
# [13]	train-auc:0.99997+0.00002	test-auc:0.90987+0.00838
# [14]	train-auc:0.99999+0.00001	test-auc:0.91428+0.00652
# [15]	train-auc:0.99999+0.00000	test-auc:0.91698+0.00702
# [16]	train-auc:1.00000+0.00000	test-auc:0.91924+0.00723
# [17]	train-auc:1.00000+0.00000	test-auc:0.92084+0.00710
# [18]	train-auc:1.00000+0.00000	test-auc:0.92079+0.00700
# [19]	train-auc:1.00000+0.00000	test-auc:0.92227+0.00700
# [20]	train-auc:1.00000+0.00000	test-auc:0.92407+0.00705
# [21]	train-auc:1.00000+0.00000	test-auc:0.92560+0.00657
# [22]	train-auc:1.00000+0.00000	test-auc:0.92616+0.00667
# [23]	train-auc:1.00000+0.00000	test-auc:0.92685+0.00647
# [24]	train-auc:1.00000+0.00000	test-auc:0.92833+0.00572
# [25]	train-auc:1.00000+0.00000	test-auc:0.92853+0.00581
# [26]	train-auc:1.00000+0.00000	test-auc:0.92973+0.00609
# [27]	train-auc:1.00000+0.00000	test-auc:0.93073+0.00593
# [28]	train-auc:1.00000+0.00000	test-auc:0.93223+0.00586
# [29]	train-auc:1.00000+0.00000	test-auc:0.93262+0.00573
# [30]	train-auc:1.00000+0.00000	test-auc:0.93368+0.00592
# [31]	train-auc:1.00000+0.00000	test-auc:0.93418+0.00557
# [32]	train-auc:1.00000+0.00000	test-auc:0.93483+0.00549
# [33]	train-auc:1.00000+0.00000	test-auc:0.93549+0.00571
# [34]	train-auc:1.00000+0.00000	test-auc:0.93584+0.00609
# [35]	train-auc:1.00000+0.00000	test-auc:0.93601+0.00577
# [36]	train-auc:1.00000+0.00000	test-auc:0.93588+0.00590
# [37]	train-auc:1.00000+0.00000	test-auc:0.93644+0.00567
# [38]	train-auc:1.00000+0.00000	test-auc:0.93667+0.00541
# [39]	train-auc:1.00000+0.00000	test-auc:0.93722+0.00541
# [40]	train-auc:1.00000+0.00000	test-auc:0.93705+0.00564
# [41]	train-auc:1.00000+0.00000	test-auc:0.93726+0.00589
# [42]	train-auc:1.00000+0.00000	test-auc:0.93750+0.00577
# [43]	train-auc:1.00000+0.00000	test-auc:0.93784+0.00559
# [44]	train-auc:1.00000+0.00000	test-auc:0.93831+0.00560
# [45]	train-auc:1.00000+0.00000	test-auc:0.93870+0.00549
# [46]	train-auc:1.00000+0.00000	test-auc:0.93882+0.00540
# [47]	train-auc:1.00000+0.00000	test-auc:0.93906+0.00541
# [48]	train-auc:1.00000+0.00000	test-auc:0.93911+0.00554
# [49]	train-auc:1.00000+0.00000	test-auc:0.93944+0.00553
# [50]	train-auc:1.00000+0.00000	test-auc:0.93948+0.00530
# [51]	train-auc:1.00000+0.00000	test-auc:0.93938+0.00523
# [52]	train-auc:1.00000+0.00000	test-auc:0.93970+0.00542
# [53]	train-auc:1.00000+0.00000	test-auc:0.93978+0.00534
# [54]	train-auc:1.00000+0.00000	test-auc:0.93986+0.00533
# [55]	train-auc:1.00000+0.00000	test-auc:0.94011+0.00532
# [56]	train-auc:1.00000+0.00000	test-auc:0.94018+0.00497
# [57]	train-auc:1.00000+0.00000	test-auc:0.94039+0.00499
# [58]	train-auc:1.00000+0.00000	test-auc:0.94056+0.00495
# [59]	train-auc:1.00000+0.00000	test-auc:0.94039+0.00499
# [60]	train-auc:1.00000+0.00000	test-auc:0.94048+0.00510
# [61]	train-auc:1.00000+0.00000	test-auc:0.94055+0.00509
# [62]	train-auc:1.00000+0.00000	test-auc:0.94077+0.00495
# [63]	train-auc:1.00000+0.00000	test-auc:0.94084+0.00499
# [64]	train-auc:1.00000+0.00000	test-auc:0.94093+0.00509
# [65]	train-auc:1.00000+0.00000	test-auc:0.94096+0.00500
# [66]	train-auc:1.00000+0.00000	test-auc:0.94127+0.00523
# [67]	train-auc:1.00000+0.00000	test-auc:0.94137+0.00536
# [68]	train-auc:1.00000+0.00000	test-auc:0.94161+0.00522
# [69]	train-auc:1.00000+0.00000	test-auc:0.94154+0.00530
# [70]	train-auc:1.00000+0.00000	test-auc:0.94148+0.00530
# [71]	train-auc:1.00000+0.00000	test-auc:0.94162+0.00534
# [72]	train-auc:1.00000+0.00000	test-auc:0.94164+0.00519
# [73]	train-auc:1.00000+0.00000	test-auc:0.94164+0.00521
# [74]	train-auc:1.00000+0.00000	test-auc:0.94173+0.00531
# [75]	train-auc:1.00000+0.00000	test-auc:0.94180+0.00516
# [76]	train-auc:1.00000+0.00000	test-auc:0.94185+0.00529
# [77]	train-auc:1.00000+0.00000	test-auc:0.94185+0.00548
# [78]	train-auc:1.00000+0.00000	test-auc:0.94192+0.00531
# [79]	train-auc:1.00000+0.00000	test-auc:0.94188+0.00551
# [80]	train-auc:1.00000+0.00000	test-auc:0.94190+0.00550
# [81]	train-auc:1.00000+0.00000	test-auc:0.94196+0.00549
# [82]	train-auc:1.00000+0.00000	test-auc:0.94203+0.00556
# [83]	train-auc:1.00000+0.00000	test-auc:0.94199+0.00559
# [84]	train-auc:1.00000+0.00000	test-auc:0.94199+0.00557
# [85]	train-auc:1.00000+0.00000	test-auc:0.94216+0.00566
# [86]	train-auc:1.00000+0.00000	test-auc:0.94218+0.00563
# [87]	train-auc:1.00000+0.00000	test-auc:0.94211+0.00578
# [88]	train-auc:1.00000+0.00000	test-auc:0.94228+0.00565
# [89]	train-auc:1.00000+0.00000	test-auc:0.94242+0.00558
# [90]	train-auc:1.00000+0.00000	test-auc:0.94239+0.00551
# [91]	train-auc:1.00000+0.00000	test-auc:0.94239+0.00553
# [92]	train-auc:1.00000+0.00000	test-auc:0.94255+0.00534
# [93]	train-auc:1.00000+0.00000	test-auc:0.94261+0.00541
# [94]	train-auc:1.00000+0.00000	test-auc:0.94258+0.00551
# [95]	train-auc:1.00000+0.00000	test-auc:0.94264+0.00554
# [96]	train-auc:1.00000+0.00000	test-auc:0.94268+0.00561
# [97]	train-auc:1.00000+0.00000	test-auc:0.94270+0.00562
# [98]	train-auc:1.00000+0.00000	test-auc:0.94277+0.00564
# [99]	train-auc:1.00000+0.00000	test-auc:0.94283+0.00568
# Wall time: 1min 8s

# %%
stuff
# Out:
#     train-auc-mean  train-auc-std  test-auc-mean  test-auc-std
# 0         0.860737       0.014675       0.789106      0.011345
# 1         0.923195       0.004303       0.834484      0.014205
# 2         0.957201       0.004688       0.851694      0.012766
# 3         0.972898       0.003031       0.862831      0.010259
# 4         0.984664       0.001488       0.869819      0.007687
# ..             ...            ...            ...           ...
# 95        1.000000       0.000000       0.942644      0.005535
# 96        1.000000       0.000000       0.942675      0.005611
# 97        1.000000       0.000000       0.942701      0.005617
# 98        1.000000       0.000000       0.942772      0.005639
# 99        1.000000       0.000000       0.942832      0.005676
#
# [100 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,10)
plt.plot(stuff['train-auc-mean'], label='Training AUC')
plt.plot(stuff['test-auc-mean'], label='Test AUC')
plt.legend()

# %%
xgb.plot_importance(xgb_scores)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (80,10)
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)
xgb.plot_tree(xgb_scores, num_trees=75)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\xgboost\plotting.py in to_graphviz(booster, fmap, num_trees, rankdir, yes_color, no_color, condition_node_params, leaf_node_params, **kwargs)
#     196     try:
# --> 197         from graphviz import Source
#     198     except ImportError as e:
#
# ModuleNotFoundError: No module named 'graphviz'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14020\4190193776.py in <module>
#       4
#       5 figure(figsize=(8, 6), dpi=80)
# ----> 6 xgb.plot_tree(xgb_scores, num_trees=75)
#
# D:\Anaconda\lib\site-packages\xgboost\plotting.py in plot_tree(booster, fmap, num_trees, rankdir, ax, **kwargs)
#     278         _, ax = plt.subplots(1, 1)
#     279
# --> 280     g = to_graphviz(booster, fmap=fmap, num_trees=num_trees, rankdir=rankdir,
#     281                     **kwargs)
#     282
#
# D:\Anaconda\lib\site-packages\xgboost\plotting.py in to_graphviz(booster, fmap, num_trees, rankdir, yes_color, no_color, condition_node_params, leaf_node_params, **kwargs)
#     197         from graphviz import Source
#     198     except ImportError as e:
# --> 199         raise ImportError('You must install graphviz to plot tree') from e
#     200     if isinstance(booster, XGBModel):
#     201         booster = booster.get_booster()
#
# ImportError: You must install graphviz to plot tree

# %%
from xgboost import XGBClassifier
my_model = XGBClassifier(subsample=0.8,
          max_depth=30,
          eval_metric='auc',
          objective='binary:logistic',
          n_estimators=1000,
          verbosity=1,
          early_stopping_rounds=10)

# %%
my_model.fit(Xtrain, ytrain, eval_set=[(Xtest, ytest)])

# %%
x=my_model.get_booster()

# %%
x.best_iteration
